# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
a = tf.random.normal([2, 20]) # 2x20 matrix of random numbers
out = a.numpy()
x, y = out                    # Split 2x20 matrix into 2 vectors 1x10
plt.scatter(x, y)
plt.show()
